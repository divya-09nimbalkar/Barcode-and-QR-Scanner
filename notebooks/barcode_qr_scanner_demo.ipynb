# %%
# Barcode & QR Scanner Demo

# --- Install dependencies (only needed once per environment) ---
# !pip install opencv-python qrcode pyzbar matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyzbar[scripts]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyzbar-win64
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pyzbar-win64 (from versions: none)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for pyzbar-win64

# %%
# --- Imports ---
import cv2
import qrcode

import matplotlib.pyplot as plt

# %%
import cv2

detector = cv2.QRCodeDetector()
img = cv2.imread(r"D:\Projects all\All GITHUB PROJECTS TO UPLOAD\Z FOLDERS OF ALL THE MAIN TOPICS\Computer_Vision\Barcode_and_QR_Scanner\data\raw\test_qr.png")
data, bbox, _ = detector.detectAndDecode(img)
print("OpenCV QR result:", data)
# Out:
# OpenCV QR result: Hello Copilot!
